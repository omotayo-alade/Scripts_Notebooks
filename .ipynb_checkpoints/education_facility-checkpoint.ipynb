# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv('education_facility.csv')

# %%
df.head()
# Out:
#                  facility_name                         facility_type_display  \
# 0                    CPS SWALI                           Primary school only
# 1           NANA Basic Academy  Primary and Junior Secondary school combined
# 2  L.E.A Primary School Pabeyi                           Primary school only
# 3   L.E.A.PrimarySchoolPagadna                           Primary school only
# 4              Syflora Academy                           Primary school only
#
#   improved_water_supply improved_sanitation chalkboard_each_classroom_yn  \
# 0                  True                True                        False
# 1                 False               False                          NaN
# 2                  True                True                        False
# 3                 False                True                        False
# 4                 False                True                         True
#
#    num_tchrs_with_nce  num_tchr_full_time  num_students_total  \
# 0                 9.0                 9.0               776.0
# 1                 NaN                 NaN                 NaN
# 2                 9.0                11.0               283.0
# 3                 4.0                 5.0               247.0
# 4                 4.0                 8.0                66.0
#
#    num_classrms_total phcn_electricity  ...  community   ward  management  \
# 0                12.0            False  ...      Swali      3      public
# 1                 NaN            False  ...      Mpape  Dutse     private
# 2                 9.0            False  ...     Pabeyi   Dobi      public
# 3                 7.0            False  ...    Pagadna   Dobi      public
# 4                10.0             True  ...      Mpape  Dutse     private
#
#       sector   formhub_photo_id  \
# 0  education  1393404015008.jpg
# 1  education  1396960914896.jpg
# 2  education  1397575395444.jpg
# 3  education  1398262573409.jpg
# 4  education  1396959110576.jpg
#
#                                              gps  \
# 0                 4.91691036 6.27412844 31.5 5.0
# 1  9.140918333333333 7.496761666666667 697.0 4.5
# 2          9.174855 7.0220616666666675 236.8 5.0
# 3  9.115846666666666 6.962314999999999 216.5 4.4
# 4           9.141155 7.499665000000001 693.2 4.7
#
#                               survey_id       unique_lga  latitude longitude
# 0  51885096-65a1-4f1f-8c2a-3b11d9ae40bb  bayelsa_yenagoa  4.916910  6.274128
# 1  7f3ea41a-e4cb-41dd-85fc-5fa54c42d09f        fct_bwari  9.140918  7.496762
# 2  56f2e625-ec43-4c39-97a8-d6379dceefa2   fct_gwagwalada  9.174855  7.022062
# 3  2932eda8-64b1-4068-8412-3b2e099062fc   fct_gwagwalada  9.115847  6.962315
# 4  e17acb1e-364a-4a90-9384-0d612bb240c5        fct_bwari  9.141155  7.499665
#
# [5 rows x 28 columns]

# %%
df.columns, df.shape
# Out:
# (Index(['facility_name', 'facility_type_display', 'improved_water_supply',
#         'improved_sanitation', 'chalkboard_each_classroom_yn',
#         'num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_total',
#         'num_classrms_total', 'phcn_electricity', 'num_toilets_total',
#         'num_students_male', 'num_students_female', 'num_tchrs_male',
#         'num_tchrs_female', 'date_of_survey', 'education_type', 'facility_id',
#         'community', 'ward', 'management', 'sector', 'formhub_photo_id', 'gps',
#         'survey_id', 'unique_lga', 'latitude', 'longitude'],
#        dtype='object'),
#  (98667, 28))

# %%
# Rename Columns
df.columns = ['facility_name', 'facility_type_display', 'improved_water_supply',
        'improved_sanitation', 'chalkboard_each_classroom',
        'num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_total',
        'num_classrms_total', 'phcn_electricity', 'num_toilets_total',
        'num_students_male', 'num_students_female', 'num_tchrs_male',
        'num_tchrs_female', 'date_of_survey', 'education_type', 'facility_id',
        'community', 'ward', 'management', 'sector', 'formhub_photo_id', 'gps',
        'survey_id', 'unique_lga', 'latitude', 'longitude']

# %%
#drop irrelevant columns
df.drop(['education_type', 'community', 'ward', 'facility_type_display', 'formhub_photo_id', 'gps', 'survey_id', 'latitude',
       'longitude', 'date_of_survey', 'sector'], axis=1, inplace=True)
df.head(2)

# %%
#Check if there are missing values
df.isnull().any()
# Out:
# facility_id                  False
# facility_name                 True
# improved_water_supply         True
# improved_sanitation           True
# chalkboard_each_classroom     True
# num_tchrs_with_nce            True
# num_tchr_full_time            True
# num_students_total            True
# num_classrms_total            True
# phcn_electricity              True
# num_toilets_total             True
# num_students_male             True
# num_students_female           True
# num_tchrs_male                True
# num_tchrs_female              True
# management                    True
# unique_lga                    True
# dtype: bool

# %%
#check the total number of missing values for each column
df.isnull().sum()
# Out:
# facility_id                     0
# facility_name                 214
# improved_water_supply         279
# improved_sanitation           297
# chalkboard_each_classroom    2161
# num_tchrs_with_nce           3530
# num_tchr_full_time           2164
# num_students_total           5262
# num_classrms_total           3292
# phcn_electricity              277
# num_toilets_total            2962
# num_students_male            4375
# num_students_female          4346
# num_tchrs_male               3680
# num_tchrs_female             3319
# management                   1223
# unique_lga                      1
# dtype: int64

# %%
#check dataset shape to decide whether to drop missing values on rows or column
df.shape
# Out:
# (98667, 17)

# %%
#Since dataset appears to have almost 99,000 rows, drop rows with missing values and retain all attributes(columns)
df.dropna(axis=0, inplace=True)

# %%
#Check to see if there are still missing values
df.isnull().sum().any()
# Out:
# False

# %%
#Check the new shape of data
df.shape
# Out:
# (87387, 17)

# %%
df.head()
# Out:
#   facility_id                facility_name improved_water_supply  \
# 0       EIRJK                    CPS SWALI                  True
# 2       EDJJK  L.E.A Primary School Pabeyi                  True
# 3       ELOOD   L.E.A.PrimarySchoolPagadna                 False
# 4       EZJOH              Syflora Academy                 False
# 5       EULMF           Nomadic Paiko Kore                  True
#
#   improved_sanitation chalkboard_each_classroom  num_tchrs_with_nce  \
# 0                True                     False                 9.0
# 2                True                     False                 9.0
# 3                True                     False                 4.0
# 4                True                      True                 4.0
# 5                True                      True                 4.0
#
#    num_tchr_full_time  num_students_total  num_classrms_total  \
# 0                 9.0               776.0                12.0
# 2                11.0               283.0                 9.0
# 3                 5.0               247.0                 7.0
# 4                 8.0                66.0                10.0
# 5                 6.0               120.0                 6.0
#
#   phcn_electricity  num_toilets_total  num_students_male  num_students_female  \
# 0            False               21.0              383.0                393.0
# 2            False                2.0              185.0                 98.0
# 3            False                2.0              147.0                100.0
# 4             True                4.0               29.0                 37.0
# 5            False                2.0               44.0                 76.0
#
#    num_tchrs_male  num_tchrs_female management       unique_lga
# 0             5.0               4.0     public  bayelsa_yenagoa
# 2             9.0               2.0     public   fct_gwagwalada
# 3             5.0               0.0     public   fct_gwagwalada
# 4             2.0               6.0    private        fct_bwari
# 5             5.0               1.0     public   fct_gwagwalada

# %%
#Since all numeric features are total numbers, convert all numeric values to int
df[['num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_total',
       'num_classrms_total', 'num_toilets_total', 'num_students_male',
       'num_students_female', 'num_tchrs_male', 'num_tchrs_female']] =\
df[['num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_total',
       'num_classrms_total', 'num_toilets_total', 'num_students_male',
       'num_students_female', 'num_tchrs_male', 'num_tchrs_female']].astype(int)

# %%
df.head(2)
# Out:
#   facility_id                facility_name improved_water_supply  \
# 0       EIRJK                    CPS SWALI                  True
# 2       EDJJK  L.E.A Primary School Pabeyi                  True
#
#   improved_sanitation chalkboard_each_classroom  num_tchrs_with_nce  \
# 0                True                     False                   9
# 2                True                     False                   9
#
#    num_tchr_full_time  num_students_total  num_classrms_total  \
# 0                   9                 776                  12
# 2                  11                 283                   9
#
#   phcn_electricity  num_toilets_total  num_students_male  num_students_female  \
# 0            False                 21                383                  393
# 2            False                  2                185                   98
#
#    num_tchrs_male  num_tchrs_female management       unique_lga
# 0               5                 4     public  bayelsa_yenagoa
# 2               9                 2     public   fct_gwagwalada

# %%
#Define a new order of columns
order = ['facility_id', 'facility_name',
         'management', 'unique_lga',
         'improved_water_supply', 'improved_sanitation', 'phcn_electricity',
         'chalkboard_each_classroom', 'num_classrms_total', 'num_toilets_total',
         'num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_male',
         'num_students_female', 'num_students_total', 'num_tchrs_male', 'num_tchrs_female']

# %%
#Re-order columns
df = df[order]
df.head(2)
# Out:
#   facility_id                facility_name management       unique_lga  \
# 0       EIRJK                    CPS SWALI     public  bayelsa_yenagoa
# 2       EDJJK  L.E.A Primary School Pabeyi     public   fct_gwagwalada
#
#   improved_water_supply improved_sanitation phcn_electricity  \
# 0                  True                True            False
# 2                  True                True            False
#
#   chalkboard_each_classroom  num_classrms_total  num_toilets_total  \
# 0                     False                  12                 21
# 2                     False                   9                  2
#
#    num_tchrs_with_nce  num_tchr_full_time  num_students_male  \
# 0                   9                   9                383
# 2                   9                  11                185
#
#    num_students_female  num_students_total  num_tchrs_male  num_tchrs_female
# 0                  393                 776               5                 4
# 2                   98                 283               9                 2

# %%
states = ["Abia", "Adamawa", "Akwa_Ibom", "Anambra", "Bauchi", "Bayelsa",
          "Benue", "Borno", "Cross_River", "Delta", "Ebonyi", "Edo", 
          "Ekiti", "Enugu", "fct", "Gombe", "Imo", "Jigawa", "Kaduna",
          "Kano", "Katsina", "Kebbi", "Kogi", "Kwara", "Lagos", "Nasarawa",
          "Niger", "Ogun", "Ondo", "Osun", "Oyo", "Plateau", "Rivers",
          "Sokoto", "Taraba", "Yobe", "Zamfara"]

# %%
#Join L.G.A(s) in unique_lga into 37 unique values to represent 36 states in Nigeria plus FCT
for i in states:
    df['unique_lga'][df['unique_lga'].str.contains(i, case=False)] = i
    df['unique_lga'][df['unique_lga'].str.contains('fct', case=False)] = 'FCT - Abuja'
    df['unique_lga'][df['unique_lga'].str.contains('Cross_River', case=False)] = 'Cross River'
    df['unique_lga'][df['unique_lga'].str.contains('Akwa_Ibom', case=False)] = 'Akwa Ibom'
    pass

# %%
#Check the unique values
df['unique_lga'].unique()
# Out:
# array(['Bayelsa', 'FCT - Abuja', 'Rivers', 'Cross River', 'Delta',
#        'Kaduna', 'Sokoto', 'Katsina', 'Taraba', 'Gombe', 'Bauchi',
#        'Adamawa', 'Oyo', 'Imo', 'Abia', 'Lagos', 'Ekiti', 'Plateau',
#        'Nasarawa', 'Benue', 'Borno', 'Niger', 'Kogi', 'Akwa Ibom',
#        'Kebbi', 'Ebonyi', 'Enugu', 'Kwara', 'Ondo', 'Jigawa', 'Yobe',
#        'Ogun', 'Kano', 'Osun', 'Zamfara', 'Edo', 'Anambra'], dtype=object)

# %%
#Check the number of unique values
df['unique_lga'].nunique()
# Out:
# 37

# %%
#Rename unique_lga to state
df.rename({'unique_lga':'state'}, axis=1, inplace=True)

# %%
#Check for duplicates
df.duplicated('facility_id').value_counts()
# Out:
# False    87337
# True        50
# dtype: int64

# %%
#Drop duplicates
df.drop_duplicates(keep='first', inplace=True)

# %%
#Reset index after duplicates have been removed
df.reset_index(inplace=True)

# %%
#Check if there's still any duplicate
df.duplicated().any()
# Out:
# False

# %%
df.columns
# Out:
# Index(['facility_id', 'facility_name', 'management', 'state',
#        'improved_water_supply', 'improved_sanitation', 'phcn_electricity',
#        'chalkboard_each_classroom', 'num_classrms_total', 'num_toilets_total',
#        'num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_male',
#        'num_students_female', 'num_students_total', 'num_tchrs_male',
#        'num_tchrs_female'],
#       dtype='object')

# %%
#Since all features are total numbers of attribute they represent, rename columns for ease
df.columns = ['Facility_ID', 'Facility_name', 'Management', 'State',
       'Improved_water_supply', 'Improved_sanitation', 'Public_electricity',
       'Chalkboard/classroom', 'Classrooms', 'Toilets',
       'NCE_teachers', 'Fulltime_teachers', 'Male_students',
       'Female_students', 'Total_students', 'Male_teachers',
       'Female_teachers']

# %%
df.head()
# Out:
#   Facility_ID                Facility_name Management        State  \
# 0       EIRJK                    CPS SWALI     public      Bayelsa
# 1       EDJJK  L.E.A Primary School Pabeyi     public  FCT - Abuja
# 2       ELOOD   L.E.A.PrimarySchoolPagadna     public  FCT - Abuja
# 3       EZJOH              Syflora Academy    private  FCT - Abuja
# 4       EULMF           Nomadic Paiko Kore     public  FCT - Abuja
#
#   Improved_water_supply Improved_sanitation Public_electricity  \
# 0                  True                True              False
# 1                  True                True              False
# 2                 False                True              False
# 3                 False                True               True
# 4                  True                True              False
#
#   Chalkboard/classroom  Classrooms  Toilets  NCE_teachers  Fulltime_teachers  \
# 0                False          12       21             9                  9
# 1                False           9        2             9                 11
# 2                False           7        2             4                  5
# 3                 True          10        4             4                  8
# 4                 True           6        2             4                  6
#
#    Male_students  Female_students  Total_students  Male_teachers  \
# 0            383              393             776              5
# 1            185               98             283              9
# 2            147              100             247              5
# 3             29               37              66              2
# 4             44               76             120              5
#
#    Female_teachers
# 0                4
# 1                2
# 2                0
# 3                6
# 4                1

# %%
#Rename booleans to Yes and No to avoid issues
df[['Improved_water_supply', 'Improved_sanitation', 'Public_electricity', 'Chalkboard/classroom']]=\
df[['Improved_water_supply', 'Improved_sanitation', 'Public_electricity', 'Chalkboard/classroom']].replace([True, False], ['Yes', 'No'])

# %%
#Check categorical variables for unique values
unique = ['Management', 'Improved_water_supply', 'Improved_sanitation', 'Public_electricity', 'Chalkboard/classroom']
for i in unique:
    print(i, df[i].unique())
# Out:
# Management ['public' 'private' 'faith_based' 'none']
# Improved_water_supply ['Yes' 'No']
# Improved_sanitation ['Yes' 'No']
# Public_electricity ['No' 'Yes']
# Chalkboard/classroom ['No' 'Yes']

# %%
#Rename faith_based strings in Management column to 'private'
df['Management'][df['Management'].str.contains('faith')] = 'private'

# %%
#df['Management'][df['Management'].str.contains('none')].value_counts()
df.head()
# Out:
#   Facility_ID                Facility_name Management        State  \
# 0       EIRJK                    CPS SWALI     public      Bayelsa
# 1       EDJJK  L.E.A Primary School Pabeyi     public  FCT - Abuja
# 2       ELOOD   L.E.A.PrimarySchoolPagadna     public  FCT - Abuja
# 3       EZJOH              Syflora Academy    private  FCT - Abuja
# 4       EULMF           Nomadic Paiko Kore     public  FCT - Abuja
#
#   Improved_water_supply Improved_sanitation Public_electricity  \
# 0                   Yes                 Yes                 No
# 1                   Yes                 Yes                 No
# 2                    No                 Yes                 No
# 3                    No                 Yes                Yes
# 4                   Yes                 Yes                 No
#
#   Chalkboard/classroom  Classrooms  Toilets  NCE_teachers  Fulltime_teachers  \
# 0                   No          12       21             9                  9
# 1                   No           9        2             9                 11
# 2                   No           7        2             4                  5
# 3                  Yes          10        4             4                  8
# 4                  Yes           6        2             4                  6
#
#    Male_students  Female_students  Total_students  Male_teachers  \
# 0            383              393             776              5
# 1            185               98             283              9
# 2            147              100             247              5
# 3             29               37              66              2
# 4             44               76             120              5
#
#    Female_teachers
# 0                4
# 1                2
# 2                0
# 3                6
# 4                1

# %%
#drop rows containing 'none' in Management column
none = df['Management'] == 'none'
none_id = df[none]['Facility_ID'].tolist()
df.set_index('Facility_ID', inplace=True)
df.drop(index=none_id, inplace=True)
df.reset_index(inplace=True)

# %%
#Check for changes
unique = ['Management', 'Improved_water_supply', 'Improved_sanitation', 'Public_electricity', 'Chalkboard/classroom']
for i in unique:
    print(i, df[i].unique())
# Out:
# Management ['public' 'private']
# Improved_water_supply ['Yes' 'No']
# Improved_sanitation ['Yes' 'No']
# Public_electricity ['No' 'Yes']
# Chalkboard/classroom ['No' 'Yes']

# %%
df.to_csv('education_clean.csv')

# %%
df.head()
# Out:
#   Facility_ID                Facility_name Management        State  \
# 0       EIRJK                    CPS SWALI     public      Bayelsa
# 1       EDJJK  L.E.A Primary School Pabeyi     public  FCT - Abuja
# 2       ELOOD   L.E.A.PrimarySchoolPagadna     public  FCT - Abuja
# 3       EZJOH              Syflora Academy    private  FCT - Abuja
# 4       EULMF           Nomadic Paiko Kore     public  FCT - Abuja
#
#   Improved_water_supply Improved_sanitation Public_electricity  \
# 0                   Yes                 Yes                 No
# 1                   Yes                 Yes                 No
# 2                    No                 Yes                 No
# 3                    No                 Yes                Yes
# 4                   Yes                 Yes                 No
#
#   Chalkboard/classroom  Classrooms  Toilets  NCE_teachers  Fulltime_teachers  \
# 0                   No          12       21             9                  9
# 1                   No           9        2             9                 11
# 2                   No           7        2             4                  5
# 3                  Yes          10        4             4                  8
# 4                  Yes           6        2             4                  6
#
#    Male_students  Female_students  Total_students  Male_teachers  \
# 0            383              393             776              5
# 1            185               98             283              9
# 2            147              100             247              5
# 3             29               37              66              2
# 4             44               76             120              5
#
#    Female_teachers
# 0                4
# 1                2
# 2                0
# 3                6
# 4                1

# %%
df.hist(bins=50, figsize=(15,13))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A50ADE7248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A5263599C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A5266D34C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A52956D088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A529394148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A5293C4FC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A5293FDDC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A529438B08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A529438D08>]],
#       dtype=object)

# %%
#Plot bar char for the categorical variables
fig = plt.figure(figsize=(13,15))
ax0 = fig.add_subplot(3,2,1)
ax1 = fig.add_subplot(3,2,2)
ax2 = fig.add_subplot(3,2,3)
ax3 = fig.add_subplot(3,2,4)
ax4 = fig.add_subplot(3,2,5)

sns.barplot(df['Management'].unique(), df['Management'].value_counts(), ax=ax0)
sns.barplot(df['Improved_water_supply'].unique(), df['Improved_water_supply'].value_counts(), ax=ax1)
sns.barplot(df['Improved_sanitation'].unique(), df['Improved_sanitation'].value_counts(), ax=ax2)
sns.barplot(df['Public_electricity'].unique(), df['Public_electricity'].value_counts(), ax=ax3)
sns.barplot(df['Chalkboard/classroom'].unique(), df['Chalkboard/classroom'].value_counts(), ax=ax4)

ax0.set_title('Private and Public Schools'), ax0.set_ylabel('Count')
ax1.set_title('Improved Water Supply'), ax1.set_ylabel('Count')
ax2.set_title('Improved Sanitation'), ax2.set_ylabel('Count')
ax3.set_title('Public Electricity'), ax3.set_ylabel('Count')
ax4.set_title('Chalkboard per Classroom')

plt.show()

# %%
table = pd.crosstab(df['Management'], df['Improved_water_supply'])
table.plot(kind='bar', stacked=True,figsize=(8,6))
plt.ylabel('Frequency Distribution')
plt.show()

# %%
table = pd.crosstab(df['Management'], df['Improved_sanitation'])
table.plot(kind='bar', stacked=True,figsize=(8,6))
plt.ylabel('Frequency Distribution')
plt.show()

# %%
table = pd.crosstab(df['Management'], df['Public_electricity'])
table.plot(kind='bar', stacked=True,figsize=(8,6))
plt.ylabel('Frequency Distribution')
plt.show()

# %%
table = pd.crosstab(df['Management'], df['Chalkboard/classroom'])
table.plot(kind='bar', stacked=True,figsize=(8,6))
plt.ylabel('Frequency Distribution')
plt.show()

# %%
table = pd.crosstab(df['State'], df['Improved_water_supply'])
table.plot(kind='bar', stacked=True,figsize=(13,6))
plt.ylabel('Frequency Distribution')
plt.show()

# %%
table = pd.crosstab(df['State'], df['Improved_sanitation'])
table.plot(kind='bar', stacked=True,figsize=(13,6))
plt.ylabel('Frequency Distribution')
plt.show()

# %%
table = pd.crosstab(df['State'], df['Public_electricity'])
table.plot(kind='bar', stacked=True,figsize=(13,6))
plt.ylabel('Frequency Distribution')
plt.show()

# %%
table = pd.crosstab(df['State'], df['Chalkboard/classroom'])
table.plot(kind='bar', stacked=True,figsize=(13,6))
plt.ylabel('Frequency Distribution')
plt.show()

# %%
grouped = df.groupby('Management')[['Classrooms','Toilets','NCE_teachers','Fulltime_teachers']].sum().transpose()
grouped.plot(kind='bar', stacked=True, figsize=(13,6))
plt.ylabel('Frequency Distribution')
plt.show()

# %%
teachers = df[['Male_teachers', 'Female_teachers']].sum()
teachers.plot(kind='barh', color=['g', 'b'])
plt.title('Distribution of Teachers by Gender')
plt.xlabel('Frequency Distribution')
plt.show()

# %%
df_num = df[['Classrooms','Toilets',
              'NCE_teachers','Fulltime_teachers',
              'Male_teachers','Female_teachers','Total_students']]
df_num.head()
# Out:
#    Classrooms  Toilets  NCE_teachers  Fulltime_teachers  Male_teachers  \
# 0          12       21             9                  9              5
# 1           9        2             9                 11              9
# 2           7        2             4                  5              5
# 3          10        4             4                  8              2
# 4           6        2             4                  6              5
#
#    Female_teachers  Total_students
# 0                4             776
# 1                2             283
# 2                0             247
# 3                6              66
# 4                1             120

# %%
num_corr = df_num.corr()
#mask = num_corr < 0.5
plt.figure(figsize=(11,7))
sns.heatmap(num_corr, annot=True, cmap="YlGnBu", square=True)
plt.show()

# %%
corr = df_num.corr()['Total_students'][:-1]
corr_fairly = corr[abs(corr) > 0.4]
print('There are {} attributes fairly correlated with Total Students:\n{}'.format(len(corr_fairly), corr_fairly))
# Out:
# There are 4 attributes fairly correlated with Total Students:
# Classrooms           0.403313
# NCE_teachers         0.425805
# Fulltime_teachers    0.512566
# Female_teachers      0.423609
# Name: Total_students, dtype: float64
