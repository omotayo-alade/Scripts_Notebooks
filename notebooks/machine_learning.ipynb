# %%
import sklearn
import pandas as pd
import numpy as np
import scipy as sp
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')

# %%
print('Pandas version:', pd.__version__,
      'NumPy version:', np.__version__,
      'SciPy version:', sp.__version__,
      'Sklearn version:', sklearn.__version__)
# Out:
# Pandas version: 1.0.3 NumPy version: 1.18.3 SciPy version: 1.4.1 Sklearn version: 0.22.2.post1

# %%
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()
#print(cancer.DESCR)

# %%
cancer.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
#cancer.values()

# %%
len(cancer.feature_names)
cancer.feature_names
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
cancer.data
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, ..., 2.654e-01, 4.601e-01,
#         1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, ..., 1.860e-01, 2.750e-01,
#         8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, ..., 2.430e-01, 3.613e-01,
#         8.758e-02],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, ..., 1.418e-01, 2.218e-01,
#         7.820e-02],
#        [2.060e+01, 2.933e+01, 1.401e+02, ..., 2.650e-01, 4.087e-01,
#         1.240e-01],
#        [7.760e+00, 2.454e+01, 4.792e+01, ..., 0.000e+00, 2.871e-01,
#         7.039e-02]])

# %%
#cancer.target

# %%
cancer.target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %%
cancer.filename
# Out:
# 'C:\\Users\\Omotosho\\AppData\\Roaming\\Python\\Python37\\site-packages\\sklearn\\datasets\\data\\breast_cancer.csv'

# %%
df_features = pd.DataFrame(cancer.data, columns=cancer.feature_names)
df_target = pd.DataFrame(cancer.target, columns=['cancer'])

# %%
df = pd.concat([df_features, df_target], axis=1)

# %%
df.shape
# Out:
# (569, 31)

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()

# %%
boston.DESCR
# Out:
# ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,0
# ...

# %%
boston.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
#boston.target

# %%
boston.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
boston.data.shape
# Out:
# (506, 13)

# %%
len(boston.feature_names)
# Out:
# 13

# %%
df = pd.DataFrame(boston.data, columns = boston.feature_names)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df = pd.read_csv("../datasets/housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.isnull().any()
# Out:
# longitude             False
# latitude              False
# housing_median_age    False
# total_rooms           False
# total_bedrooms         True
# population            False
# households            False
# median_income         False
# median_house_value    False
# ocean_proximity       False
# dtype: bool

# %%
df.dropna(inplace=True)

# %%
df.isnull().any()
# Out:
# longitude             False
# latitude              False
# housing_median_age    False
# total_rooms           False
# total_bedrooms        False
# population            False
# households            False
# median_income         False
# median_house_value    False
# ocean_proximity       False
# dtype: bool

# %%
df.duplicated().any()
# Out:
# False

# %%
df.shape
# Out:
# (20433, 10)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
sns.pairplot(df)

# %%
fig, ax = plt.subplots(figsize=(8,8))
sns.heatmap(df.corr(), annot=True, square=True)
plt.show()

# %%
sns.scatterplot(df['median_income'], df['median_house_value'])

# %%
df.loc[df['median_house_value'] == 500001].count()
# Out:
# longitude             958
# latitude              958
# housing_median_age    958
# total_rooms           958
# total_bedrooms        958
# population            958
# households            958
# median_income         958
# median_house_value    958
# ocean_proximity       958
# dtype: int64

# %%
df = df.drop(df.loc[df['median_house_value'] == 500001].index)

# %%
df.shape
# Out:
# (19475, 10)

# %%
sns.scatterplot(df['median_income'], df['median_house_value'])

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df = pd.get_dummies(df, columns=['ocean_proximity'])

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# 0                          0                       0                       0
# ...

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity_<1H OCEAN',
#        'ocean_proximity_INLAND', 'ocean_proximity_ISLAND',
#        'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
df = df[['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income',
       'ocean_proximity_<1H OCEAN',
       'ocean_proximity_INLAND', 'ocean_proximity_ISLAND',
       'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN', 'median_house_value']]

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  ocean_proximity_<1H OCEAN  \
# 0       322.0       126.0         8.3252                          0
# 1      2401.0      1138.0         8.3014                          0
# 2       496.0       177.0         7.2574                          0
# 3       558.0       219.0         5.6431                          0
# 4       565.0       259.0         3.8462                          0
#
#    ocean_proximity_INLAND  ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
X = df.drop('median_house_value', axis=1)
Y = df['median_house_value']

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.2)

# %%
x_train.shape, x_test.shape
# Out:
# ((15580, 13), (3895, 13))

# %%
linear_model = LinearRegression(normalize=True).fit(x_train,y_train)
linear_model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
linear_model.score(x_train, y_train)
# Out:
# 0.6166644261651454

# %%
y_pred = linear_model.predict(x_test)
y_pred
# Out:
# array([225344., 261120., 191872., ..., 195264., 262528., 189440.])

# %%
predictors = X.columns

# %%
coef = pd.Series(linear_model.coef_, predictors).sort_values(ascending=True)
print(coef)
# Out:
# ocean_proximity_INLAND       -2.974265e+17
# ocean_proximity_NEAR BAY     -2.974265e+17
# ocean_proximity_<1H OCEAN    -2.974265e+17
# ocean_proximity_NEAR OCEAN   -2.974265e+17
# ocean_proximity_ISLAND       -2.974265e+17
# longitude                    -2.431910e+04
# latitude                     -2.244187e+04
# population                   -3.460138e+01
# total_rooms                  -6.699866e+00
# households                    5.632739e+01
# total_bedrooms                8.674232e+01
# housing_median_age            8.892299e+02
# median_income                 3.802823e+04
# dtype: float64

# %%
y_pred_actual = pd.DataFrame({'predicted':y_pred,'actual':y_test})
y_pred_actual.head(10)
# Out:
#        predicted    actual
# 7082    225344.0  174800.0
# 19365   261120.0  232600.0
# 20150   191872.0  189900.0
# 13821   172992.0  170600.0
# 19813    90560.0  118800.0
# 7397    126720.0  109100.0
# 17489   206272.0  228200.0
# 426     243712.0  287500.0
# 5340    233472.0  336300.0
# 7994    233536.0  212600.0

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5951245092433199

# %%
sns.scatterplot(x=y_test, y=y_pred)

# %%
ax = sns.distplot(y_test, hist=False, label='Actual')
sns.distplot(y_pred, hist=False, color='r', label='Predicted', ax=ax)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  ocean_proximity_<1H OCEAN  \
# 0       322.0       126.0         8.3252                          0
# 1      2401.0      1138.0         8.3014                          0
# 2       496.0       177.0         7.2574                          0
# 3       558.0       219.0         5.6431                          0
# 4       565.0       259.0         3.8462                          0
#
#    ocean_proximity_INLAND  ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# ...

# %%
median = df['median_house_value'].median()
median
# Out:
# 173800.0

# %%
df['above_median'] = (df['median_house_value'] - median) > 0

# %%
df.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13929    -114.61     34.83                31.0       2478.0           464.0
# 4094     -118.40     34.15                41.0       2394.0           500.0
# 4241     -118.32     34.11                48.0       4472.0          1579.0
# 9626     -120.25     37.23                34.0       1656.0           328.0
# 694      -122.11     37.70                29.0       1298.0           306.0
#
#        population  households  median_income  ocean_proximity_<1H OCEAN  \
# 13929      1346.0       479.0         3.2120                          0
# 4094        837.0       417.0         4.3889                          1
# 4241       2796.0      1397.0         2.3974                          1
# 9626       1110.0       332.0         2.1845                          0
# 694         835.0       338.0         2.3274                          0
#
#        ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# ...

# %%
X = df.drop(['median_house_value', 'above_median'], axis=1)
Y = df['above_median']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
x_train.shape, x_test.shape
# Out:
# ((15580, 13), (3895, 13))

# %%
y_train.shape, y_test.shape
# Out:
# ((15580,), (3895,))

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model = LogisticRegression(solver='liblinear').fit(x_train, y_train)

# %%
print('Training Score: ', logistic_model.score(x_train, y_train))
# Out:
# Training Score:  0.8224646983311938

# %%
y_pred = logistic_model.predict(x_test)

# %%
df_pred_actual = pd.DataFrame({'predicted':y_pred, 'actual':y_test})
df_pred_actual.head(10)
# Out:
#        predicted  actual
# 11150       True    True
# 13561       True   False
# 6670       False    True
# 11992      False   False
# 11274       True    True
# 10549       True   False
# 10747       True   False
# 10504       True    True
# 4526       False   False
# 15910       True    True

# %%
from sklearn.metrics import accuracy_score

# %%
print('Accuracy Score :', accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score : 0.8120667522464698

# %%
import sidetable as stb

# %%
help(df_pred_actual.stb.freq)
# Out:
# Help on method freq in module sidetable.sidetable:
#
# freq(cols, thresh=1, other_label='Others', clip_0=True, value=None, style=False) method of sidetable.sidetable.SideTableAccessor instance
#     Create a table that counts the frequency of occurrence or summation of values
#     for one or more columns of data. Table is sorted and includes cumulative
#     values which can be useful for identifying a cutoff.
#
#     Example of Titanic df.stb.freq(['class']):
#                     class   Count   Percent     Cumulative Count    Cumulative Percent
#             0       Third   491         0.551066    491                     0.551066
#             1       First   216         0.242424    707                     0.793490
#             2       Second  184         0.206510    891                     1.000000
#
#     Args:
#         cols (list):       dataframe column names that will be grouped together
#         thresh (float):    all values after this percentage will be combined into a
# ...

# %%
df_auto = pd.read_csv('../datasets/auto-mpg.csv')

# %%
df_auto.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
X = np.array(df_auto['age']).reshape(-1,1)
Y = df_auto['mpg']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
x_train.shape, x_test.shape
# Out:
# ((318, 1), (80, 1))

# %%
linear_model = LinearRegression(normalize=True).fit(x_train, y_train)
y_pred = linear_model.predict(x_test)

# %%
print('Training score: ', linear_model.score(x_train, y_train),
      'Testing score: ', r2_score(y_test, y_pred))
# Out:
# Training score:  0.32122723738565295 Testing score:  0.30555463889400514

# %%
fig, ax = plt.subplots(figsize=(8,6))
plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color='r')
plt.show()

# %%
X = np.array(df_auto['horsepower']).reshape(len(df_auto['horsepower']), 1)
Y = df_auto['mpg']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
linear_model = LinearRegression(normalize=True).fit(x_train, y_train)
y_pred = linear_model.predict(x_test)
print('Training score: ', linear_model.score(x_train, y_train),
      'Testing score: ', r2_score(y_test, y_pred))
# Out:
# Training score:  0.5896853418839274 Testing score:  0.6128305378897443

# %%
fig, ax = plt.subplots(figsize=(12,6))
plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color='r')
plt.show()

# %%
df_auto = pd.get_dummies(df_auto, columns=['origin'])

# %%
df_auto.to_csv('../datasets/auto-mpg.csv')

# %%
X = df_auto.drop('mpg', axis=1)
Y = df_auto['mpg']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
linear_model = LinearRegression(normalize=True).fit(x_train, y_train)
y_pred = linear_model.predict(x_test)
print('Training score: ', linear_model.score(x_train, y_train),
      'Testing score: ', r2_score(y_test, y_pred))

# %%
fig, ax = plt.subplots(figsize=(12,6))
plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color='r')
plt.show()
